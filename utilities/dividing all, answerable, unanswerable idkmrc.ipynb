# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
from collections import OrderedDict
import pandas as pd
import re
from tqdm import tqdm
import string
import collections
import numpy as np

from io import StringIO
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# %%
prefix = "https://huggingface.co/muhammadravi251001/fine-tuned-FilteringNLI-"
suffix = "/blob/main/results/evaluation/metric_result.txt"

suffix_df = "/raw/main/results/output/output_df.csv"
suffix_squadid_df = "/resolve/main/results/output/output_df.csv"

# %%
def take_all_url_nli_validator(data, df=False):
    
    if not df:
        baseline = f"{prefix}indonli_mnli-{data}-TQ2-TS4-MS3-VA0-TH0.0{suffix}"
    else:
        if data == "idkmrc" or data == "tydiqaid":
            baseline = f"{prefix}indonli_mnli-{data}-TQ2-TS4-MS3-VA0-TH0.0{suffix_df}"
        elif data == "squadid":
            baseline = f"{prefix}indonli_mnli-{data}-TQ2-TS4-MS3-VA0-TH0.0{suffix_squadid_df}"
    
    msc_arr = ["indonli", "indonli_mnli", f"indonli_mnli_{data}-nli"]
    tq_arr = [1, 2]
    msi_arr = [1, 2, 3]
    var_arr = [1, 2, 3]
    th_arr = [0.25, 0.5, 0.75]

    url_arr = []
    url_arr.append(baseline)

    for msc in msc_arr:
        for tq in tq_arr:
            for msi in msi_arr:
                for var in var_arr:
                    for th in th_arr:
                        
                        if msc == "indonli" or msc == "indonli_mnli":
                            var = 1
                            th = 0.0

                        if var == 1:
                            th = 0.0
                            
                        if (var == 3) and (msi == 1):
                            continue
                        
                        if not df:
                            url_arr.append(f"{prefix}{msc}-{data}-TQ{tq}-TS4-MS{msi}-VA{var}-TH{th}{suffix}")
                        else:
                            if data == "idkmrc" or data == "tydiqaid":
                                url_arr.append(f"{prefix}{msc}-{data}-TQ{tq}-TS4-MS{msi}-VA{var}-TH{th}{suffix_df}")
                            elif data == "squadid":
                                url_arr.append(f"{prefix}{msc}-{data}-TQ{tq}-TS4-MS{msi}-VA{var}-TH{th}{suffix_squadid_df}")
    
    url_arr = list(OrderedDict.fromkeys(url_arr))
    print("Amount of url:", len(url_arr))
    return url_arr

# %%
def take_dataframe(url): 
    
    response = requests.get(url)
    
    if response.status_code == 200:
        csv_data = StringIO(response.text)
        df = pd.read_csv(csv_data, index_col=0)
        df = df[['Prediction Answer', 'Rec. Pred Answer', 'Gold Answer', 'Properties']]
        df.fillna('', inplace=True)
    
    else:
        print("Failed to download CSV")
    
    return df

# %%
def normalize_text(s):
    def remove_articles(text):
        regex = re.compile(r"\b(a|an|the)\b", re.UNICODE)
        return re.sub(regex, " ", text)
    def white_space_fix(text):
        return " ".join(text.split())
    def remove_punc(text):
        exclude = set(string.punctuation)
        return "".join(ch for ch in text if ch not in exclude)
    def lower(text):
        return text.lower()
    return white_space_fix(remove_articles(remove_punc(lower(s))))

def compute_f1(pred, gold):
    pred_tokens = normalize_text(pred).split() # True positive + False positive = Untuk precision
    gold_tokens = normalize_text(gold).split() # True positive + False negatives = Untuk recall
    common = collections.Counter(pred_tokens) & collections.Counter(gold_tokens)
    num_same = sum(common.values()) # True positive

    if len(gold_tokens) == 0 or len(pred_tokens) == 0: 
        return int(gold_tokens == pred_tokens)

    if num_same == 0:
        return 0

    precision = 1.0 * num_same / len(pred_tokens)
    recall = 1.0 * num_same / len(gold_tokens)
    f1 = (2.0 * precision * recall) / (precision + recall)

    return f1

def compute_metrics_from_df(df):

    denominator = len(df)
    total_correct = 0
    f1_array = []

    for i in range(len(df)):

        pred_answer = df["Prediction Answer"][i]
        gold_answer = df["Gold Answer"][i]

        if pred_answer == gold_answer:
            total_correct += 1

        f1 = compute_f1(pred=pred_answer, gold=gold_answer)

        f1_array.append(f1)

    exact_match = ((total_correct / denominator) * 100.0)
    final_f1 = np.mean(f1_array) * 100.0

    return {'exact_match': exact_match, 'f1': final_f1}

# %%
def take_accepted_and_rejected_qa_em_f1_with_nli(url, variation):
    
    df = take_dataframe(url)
    
    if variation == "all":
        pass
    elif variation == "answerable":
        df = df[df['Gold Answer'] != ""].reset_index(drop=True)
    elif variation == "unanswerable":
        df = df[df['Gold Answer'] == ""].reset_index(drop=True)
    
    right_pred_model_qa_and_accepted_by_nli_ctr = 0
    right_pred_model_qa_and_rejected_by_nli_ctr = 0
    wrong_pred_model_qa_and_accepted_by_nli_ctr = 0
    wrong_pred_model_qa_and_rejected_by_nli_ctr = 0
    
    for i in range(len(df)):
        
        gold_answer = df['Gold Answer'][i]
        qa_generated_answer = eval(df['Rec. Pred Answer'][i])[0]
        nli_validated_answer = df['Prediction Answer'][i]
    
        # Jawaban dari model qa yg benar & di-accept sama model NLI
        right_pred_model_qa_and_accepted_by_nli = (gold_answer == qa_generated_answer) and \
            (qa_generated_answer == nli_validated_answer)

        # Jawaban dari model qa yg benar & di-reject sama model NLI
        right_pred_model_qa_and_rejected_by_nli = (gold_answer == qa_generated_answer) and \
            (qa_generated_answer != nli_validated_answer)

        # Jawaban dari model qa yg salah & di-accept sama model NLI
        wrong_pred_model_qa_and_accepted_by_nli = (gold_answer != qa_generated_answer) and \
            (qa_generated_answer == nli_validated_answer)

        # Jawaban dari model qa yg salah & di-reject sama model NLI
        wrong_pred_model_qa_and_rejected_by_nli = (gold_answer != qa_generated_answer) and \
            (qa_generated_answer != nli_validated_answer)
        
        if right_pred_model_qa_and_accepted_by_nli:
            right_pred_model_qa_and_accepted_by_nli_ctr += 1
        elif right_pred_model_qa_and_rejected_by_nli:
            right_pred_model_qa_and_rejected_by_nli_ctr += 1
        elif wrong_pred_model_qa_and_accepted_by_nli:
            wrong_pred_model_qa_and_accepted_by_nli_ctr += 1
        elif wrong_pred_model_qa_and_rejected_by_nli:
            wrong_pred_model_qa_and_rejected_by_nli_ctr += 1
            
    metric = compute_metrics_from_df(df)
    EM = metric['exact_match']
    F1 = metric['f1']
    
    return EM, F1, right_pred_model_qa_and_accepted_by_nli_ctr, right_pred_model_qa_and_rejected_by_nli_ctr, \
            wrong_pred_model_qa_and_accepted_by_nli_ctr, wrong_pred_model_qa_and_rejected_by_nli_ctr

# %%
def extract_values_nli_validator(url, data):

    msc_list = f"indonli_mnli_{data}-nli|indonli_mnli|indonli"
    pattern = re.compile(r'.*FilteringNLI-({})-{}-TQ(\d+)-TS(\d+)-MS([\d]+)-VA([\d]+)-TH([\d.]+).*'.format(msc_list, data))
    match = pattern.match(url)
    
    if match:
        msc = match.group(1)
        TQ = int(match.group(2))
        TS = int(match.group(3))
        MSI = int(match.group(4))
        VA = int(match.group(5))
        
        TH = float(match.group(6))
        if TH == '0.00':
            TH = '0.0'
        elif TH == '0.50':
            TH = '0.5'

        return msc, data, TQ, TS, MSI, VA, TH
    
    else:
        return None

# %%
def create_table_nli_validator(url_list, url_list_df, data, variation):
    
    data_list = []
    for url in tqdm(url_list, desc="Processing first URLs", unit="URL"):
        extracted_values = extract_values_nli_validator(url, data)
        data_list.append(extracted_values)

    df = pd.DataFrame(data_list, columns=['MSC', 'data', 'TQ', 'TS', 'MSI', 'VA', 'TH'])
    
    for idx, url_df in enumerate(tqdm(url_list_df, desc="Processing second URLs", unit="URL")):
        extracted_values = take_accepted_and_rejected_qa_em_f1_with_nli(url_df, variation)
        df.loc[idx, ['EM', 'F1', 'RA', 'RR', 'WA', 'WR']] = extracted_values
    
    df[['RA', 'RR', 'WA', 'WR']] = df[['RA', 'RR', 'WA', 'WR']].astype(int)
    df[['EM', 'F1']] = df[['EM', 'F1']].astype(float)
    
    df.loc[0, 'MSC'] = "Baseline"
    df.loc[0, 'TQ'] = "BL"
    df.loc[0, 'TS'] = "BL"
    df.loc[0, 'MSI'] = "BL"
    df.loc[0, 'VA'] = "BL"
    df.loc[0, 'TH'] = "BL"
    
    return df

# %% [markdown]
# # All

# %%
data = "idkmrc"
variation = "all"
url_list = take_all_url_nli_validator(data)
url_list_df = take_all_url_nli_validator(data, df=True)
table_all = pd.DataFrame(create_table_nli_validator(url_list, url_list_df, data, variation=variation))
#table_all.to_excel(f'{data}-nli-validator.xlsx', index=False)
table_all
# Out:
# Amount of url: 49
# Amount of url: 49
# Processing first URLs: 100%|████████████████████████████████████████████████████████| 49/49 [00:00<00:00, 68279.37URL/s]
# Processing second URLs: 100%|██████████████████████████████████████████████████████████| 49/49 [00:32<00:00,  1.50URL/s]
#                         MSC    data  TQ  TS MSI  VA    TH         EM  \
# 0                  Baseline  idkmrc  BL  BL  BL  BL    BL  75.829384
# 1                   indonli  idkmrc   1   4   1   1   0.0  68.483412
# 2                   indonli  idkmrc   1   4   2   1   0.0  54.620853
# 3                   indonli  idkmrc   1   4   3   1   0.0  43.957346
# 4                   indonli  idkmrc   2   4   1   1   0.0  75.355450
# 5                   indonli  idkmrc   2   4   2   1   0.0  73.933649
# 6                   indonli  idkmrc   2   4   3   1   0.0  72.630332
# 7              indonli_mnli  idkmrc   1   4   1   1   0.0  71.327014
# 8              indonli_mnli  idkmrc   1   4   2   1   0.0  61.966825
# 9              indonli_mnli  idkmrc   1   4   3   1   0.0  52.606635
# 10             indonli_mnli  idkmrc   2   4   1   1   0.0  75.473934
# 11             indonli_mnli  idkmrc   2   4   2   1   0.0  72.630332
# 12             indonli_mnli  idkmrc   2   4   3   1   0.0  71.445498
# 13  indonli_mnli_idkmrc-nli  idkmrc   1   4   1   1   0.0  75.829384
# 14  indonli_mnli_idkmrc-nli  idkmrc   1   4   1   2  0.25  75.829384
# 15  indonli_mnli_idkmrc-nli  idkmrc   1   4   1   2   0.5  75.829384
# 16  indonli_mnli_idkmrc-nli  idkmrc   1   4   1   2  0.75  75.947867
# 17  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   1   0.0  61.492891
# 18  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   2  0.25  61.492891
# 19  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   2   0.5  60.900474
# 20  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   2  0.75  57.464455
# 21  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   3  0.25  59.952607
# 22  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   3   0.5  59.241706
# 23  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   3  0.75  54.265403
# 24  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   1   0.0  56.753555
# 25  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   2  0.25  56.753555
# 26  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   2   0.5  56.042654
# 27  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   2  0.75  51.658768
# 28  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   3  0.25  54.620853
# 29  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   3   0.5  53.791469
# 30  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   3  0.75  47.393365
# 31  indonli_mnli_idkmrc-nli  idkmrc   2   4   1   1   0.0  75.829384
# 32  indonli_mnli_idkmrc-nli  idkmrc   2   4   1   2  0.25  75.829384
# 33  indonli_mnli_idkmrc-nli  idkmrc   2   4   1   2   0.5  75.829384
# 34  indonli_mnli_idkmrc-nli  idkmrc   2   4   1   2  0.75  75.947867
# 35  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   1   0.0  62.440758
# 36  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   2  0.25  62.440758
# 37  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   2   0.5  61.729858
# 38  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   2  0.75  57.938389
# 39  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   3  0.25  61.137441
# 40  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   3   0.5  60.308057
# 41  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   3  0.75  54.976303
# 42  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   1   0.0  57.819905
# 43  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   2  0.25  57.819905
# 44  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   2   0.5  56.990521
# 45  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   2  0.75  52.369668
# 46  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   3  0.25  55.924171
# 47  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   3   0.5  54.976303
# 48  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   3  0.75  48.222749
#
#            F1   RA   RR   WA  WR
# 0   84.251283  640    0  204   0
# 1   75.024827  567   73  157  47
# 2   62.089464  450  190  137  67
# 3   51.956509  361  279  133  71
# 4   83.421899  633    7  195   9
# 5   82.221935  621   19  193  11
# 6   80.936171  610   30  193  11
# 7   78.022626  589   51  153  51
# 8   69.508752  509  131  136  68
# 9   60.545604  431  209  132  72
# 10  83.895832  636    4  202   2
# 11  81.104420  611   29  199   5
# 12  79.919585  601   39  198   6
# 13  84.168344  639    1  201   3
# 14  84.168344  639    1  201   3
# 15  84.168344  639    1  201   3
# 16  84.168344  639    1  198   6
# 17  70.765575  514  126  168  36
# 18  70.765575  514  126  168  36
# 19  70.173158  509  131  168  36
# 20  66.697644  478  162  162  42
# 21  69.225291  502  138  168  36
# 22  68.514390  496  144  168  36
# 23  63.528213  452  188  161  43
# 24  66.085480  474  166  168  36
# 25  66.085480  474  166  168  36
# 26  65.374580  468  172  168  36
# 27  60.899856  429  211  162  42
# 28  63.952779  457  183  168  36
# 29  63.123395  450  190  168  36
# 30  56.723316  394  246  160  44
# 31  84.168344  639    1  201   3
# 32  84.168344  639    1  201   3
# 33  84.168344  639    1  201   3
# 34  84.168344  639    1  198   6
# 35  71.713442  522  118  168  36
# 36  71.713442  522  118  168  36
# 37  71.002542  516  124  168  36
# 38  67.171578  482  158  162  42
# 39  70.410125  512  128  168  36
# 40  69.580741  505  135  168  36
# 41  64.239114  458  182  161  43
# 42  67.151831  483  157  168  36
# 43  67.151831  483  157  168  36
# 44  66.322447  476  164  168  36
# 45  61.610757  435  205  162  42
# 46  65.256096  468  172  168  36
# 47  64.308229  460  180  168  36
# 48  57.552700  401  239  160  44

# %% [markdown]
# # Answerable only

# %%
data = "idkmrc"
variation = "answerable"
url_list = take_all_url_nli_validator(data)
url_list_df = take_all_url_nli_validator(data, df=True)
table_answerable = pd.DataFrame(create_table_nli_validator(url_list, url_list_df, data, variation=variation))
#table_answerable.to_excel(f'{data}-nli-validator.xlsx', index=False)
table_answerable
# Out:
# Amount of url: 49
# Amount of url: 49
# Processing first URLs: 100%|███████████████████████████████████████████████████████| 49/49 [00:00<00:00, 196107.73URL/s]
# Processing second URLs: 100%|██████████████████████████████████████████████████████████| 49/49 [00:35<00:00,  1.38URL/s]
#                         MSC    data  TQ  TS MSI  VA    TH         EM  \
# 0                  Baseline  idkmrc  BL  BL  BL  BL    BL  59.004739
# 1                   indonli  idkmrc   1   4   1   1   0.0  41.706161
# 2                   indonli  idkmrc   1   4   2   1   0.0  42.180095
# 3                   indonli  idkmrc   1   4   3   1   0.0  42.180095
# 4                   indonli  idkmrc   2   4   1   1   0.0  57.345972
# 5                   indonli  idkmrc   2   4   2   1   0.0  57.345972
# 6                   indonli  idkmrc   2   4   3   1   0.0  57.345972
# 7              indonli_mnli  idkmrc   1   4   1   1   0.0  46.919431
# 8              indonli_mnli  idkmrc   1   4   2   1   0.0  47.630332
# 9              indonli_mnli  idkmrc   1   4   3   1   0.0  47.630332
# 10             indonli_mnli  idkmrc   2   4   1   1   0.0  58.056872
# 11             indonli_mnli  idkmrc   2   4   2   1   0.0  58.293839
# 12             indonli_mnli  idkmrc   2   4   3   1   0.0  58.293839
# 13  indonli_mnli_idkmrc-nli  idkmrc   1   4   1   1   0.0  58.767773
# 14  indonli_mnli_idkmrc-nli  idkmrc   1   4   1   2  0.25  58.767773
# 15  indonli_mnli_idkmrc-nli  idkmrc   1   4   1   2   0.5  58.767773
# 16  indonli_mnli_idkmrc-nli  idkmrc   1   4   1   2  0.75  58.767773
# 17  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   1   0.0  59.715640
# 18  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   2  0.25  59.715640
# 19  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   2   0.5  59.715640
# 20  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   2  0.75  60.189573
# 21  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   3  0.25  59.715640
# 22  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   3   0.5  59.715640
# 23  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   3  0.75  60.189573
# 24  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   1   0.0  59.715640
# 25  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   2  0.25  59.715640
# 26  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   2   0.5  59.715640
# 27  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   2  0.75  60.189573
# 28  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   3  0.25  59.715640
# 29  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   3   0.5  59.715640
# 30  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   3  0.75  60.189573
# 31  indonli_mnli_idkmrc-nli  idkmrc   2   4   1   1   0.0  58.767773
# 32  indonli_mnli_idkmrc-nli  idkmrc   2   4   1   2  0.25  58.767773
# 33  indonli_mnli_idkmrc-nli  idkmrc   2   4   1   2   0.5  58.767773
# 34  indonli_mnli_idkmrc-nli  idkmrc   2   4   1   2  0.75  58.767773
# 35  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   1   0.0  59.715640
# 36  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   2  0.25  59.715640
# 37  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   2   0.5  59.715640
# 38  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   2  0.75  60.189573
# 39  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   3  0.25  59.715640
# 40  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   3   0.5  59.715640
# 41  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   3  0.75  60.189573
# 42  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   1   0.0  59.715640
# 43  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   2  0.25  59.715640
# 44  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   2   0.5  59.715640
# 45  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   2  0.75  60.189573
# 46  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   3  0.25  59.715640
# 47  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   3   0.5  59.715640
# 48  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   3  0.75  60.189573
#
#            F1   RA  RR   WA  WR
# 0   75.848537  249   0  173   0
# 1   54.788991  176  73  137  36
# 2   57.117317  176  73  117  56
# 3   58.178422  176  73  113  60
# 4   73.478868  242   7  167   6
# 5   73.922543  242   7  165   8
# 6   73.957649  242   7  165   8
# 7   60.310655  198  51  135  38
# 8   62.714186  198  51  118  55
# 9   63.508269  198  51  114  59
# 10  74.900669  245   4  172   1
# 11  75.242014  245   4  169   4
# 12  75.242014  245   4  168   5
# 13  75.445693  248   1  171   2
# 14  75.445693  248   1  171   2
# 15  75.445693  248   1  171   2
# 16  75.208726  248   1  169   4
# 17  78.261008  248   1  138  35
# 18  78.261008  248   1  138  35
# 19  78.261008  248   1  138  35
# 20  78.655952  248   1  133  40
# 21  78.261008  248   1  137  36
# 22  78.261008  248   1  137  36
# 23  78.715194  248   1  131  42
# 24  78.379491  248   1  138  35
# 25  78.379491  248   1  138  35
# 26  78.379491  248   1  138  35
# 27  78.671750  248   1  133  40
# 28  78.379491  248   1  137  36
# 29  78.379491  248   1  137  36
# 30  78.849475  248   1  130  43
# 31  75.445693  248   1  171   2
# 32  75.445693  248   1  171   2
# 33  75.445693  248   1  171   2
# 34  75.208726  248   1  169   4
# 35  78.261008  248   1  138  35
# 36  78.261008  248   1  138  35
# 37  78.261008  248   1  138  35
# 38  78.655952  248   1  133  40
# 39  78.261008  248   1  137  36
# 40  78.261008  248   1  137  36
# 41  78.715194  248   1  131  42
# 42  78.379491  248   1  138  35
# 43  78.379491  248   1  138  35
# 44  78.379491  248   1  138  35
# 45  78.671750  248   1  133  40
# 46  78.379491  248   1  137  36
# 47  78.379491  248   1  137  36
# 48  78.849475  248   1  130  43

# %% [markdown]
# # Unanswerable only

# %%
data = "idkmrc"
variation = "unanswerable"
url_list = take_all_url_nli_validator(data)
url_list_df = take_all_url_nli_validator(data, df=True)
table_unanswerable = pd.DataFrame(create_table_nli_validator(url_list, url_list_df, data, variation=variation))
#table_unanswerable.to_excel(f'{data}-nli-validator.xlsx', index=False)
table_unanswerable
# Out:
# Amount of url: 49
# Amount of url: 49
# Processing first URLs: 100%|███████████████████████████████████████████████████████| 49/49 [00:00<00:00, 155579.79URL/s]
# Processing second URLs: 100%|██████████████████████████████████████████████████████████| 49/49 [00:32<00:00,  1.49URL/s]
#                         MSC    data  TQ  TS MSI  VA    TH         EM  \
# 0                  Baseline  idkmrc  BL  BL  BL  BL    BL  92.654028
# 1                   indonli  idkmrc   1   4   1   1   0.0  95.260664
# 2                   indonli  idkmrc   1   4   2   1   0.0  67.061611
# 3                   indonli  idkmrc   1   4   3   1   0.0  45.734597
# 4                   indonli  idkmrc   2   4   1   1   0.0  93.364929
# 5                   indonli  idkmrc   2   4   2   1   0.0  90.521327
# 6                   indonli  idkmrc   2   4   3   1   0.0  87.914692
# 7              indonli_mnli  idkmrc   1   4   1   1   0.0  95.734597
# 8              indonli_mnli  idkmrc   1   4   2   1   0.0  76.303318
# 9              indonli_mnli  idkmrc   1   4   3   1   0.0  57.582938
# 10             indonli_mnli  idkmrc   2   4   1   1   0.0  92.890995
# 11             indonli_mnli  idkmrc   2   4   2   1   0.0  86.966825
# 12             indonli_mnli  idkmrc   2   4   3   1   0.0  84.597156
# 13  indonli_mnli_idkmrc-nli  idkmrc   1   4   1   1   0.0  92.890995
# 14  indonli_mnli_idkmrc-nli  idkmrc   1   4   1   2  0.25  92.890995
# 15  indonli_mnli_idkmrc-nli  idkmrc   1   4   1   2   0.5  92.890995
# 16  indonli_mnli_idkmrc-nli  idkmrc   1   4   1   2  0.75  93.127962
# 17  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   1   0.0  63.270142
# 18  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   2  0.25  63.270142
# 19  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   2   0.5  62.085308
# 20  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   2  0.75  54.739336
# 21  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   3  0.25  60.189573
# 22  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   3   0.5  58.767773
# 23  indonli_mnli_idkmrc-nli  idkmrc   1   4   2   3  0.75  48.341232
# 24  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   1   0.0  53.791469
# 25  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   2  0.25  53.791469
# 26  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   2   0.5  52.369668
# 27  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   2  0.75  43.127962
# 28  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   3  0.25  49.526066
# 29  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   3   0.5  47.867299
# 30  indonli_mnli_idkmrc-nli  idkmrc   1   4   3   3  0.75  34.597156
# 31  indonli_mnli_idkmrc-nli  idkmrc   2   4   1   1   0.0  92.890995
# 32  indonli_mnli_idkmrc-nli  idkmrc   2   4   1   2  0.25  92.890995
# 33  indonli_mnli_idkmrc-nli  idkmrc   2   4   1   2   0.5  92.890995
# 34  indonli_mnli_idkmrc-nli  idkmrc   2   4   1   2  0.75  93.127962
# 35  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   1   0.0  65.165877
# 36  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   2  0.25  65.165877
# 37  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   2   0.5  63.744076
# 38  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   2  0.75  55.687204
# 39  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   3  0.25  62.559242
# 40  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   3   0.5  60.900474
# 41  indonli_mnli_idkmrc-nli  idkmrc   2   4   2   3  0.75  49.763033
# 42  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   1   0.0  55.924171
# 43  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   2  0.25  55.924171
# 44  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   2   0.5  54.265403
# 45  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   2  0.75  44.549763
# 46  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   3  0.25  52.132701
# 47  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   3   0.5  50.236967
# 48  indonli_mnli_idkmrc-nli  idkmrc   2   4   3   3  0.75  36.255924
#
#            F1   RA   RR  WA  WR
# 0   92.654028  391    0  31   0
# 1   95.260664  391    0  20  11
# 2   67.061611  274  117  20  11
# 3   45.734597  185  206  20  11
# 4   93.364929  391    0  28   3
# 5   90.521327  379   12  28   3
# 6   87.914692  368   23  28   3
# 7   95.734597  391    0  18  13
# 8   76.303318  311   80  18  13
# 9   57.582938  233  158  18  13
# 10  92.890995  391    0  30   1
# 11  86.966825  366   25  30   1
# 12  84.597156  356   35  30   1
# 13  92.890995  391    0  30   1
# 14  92.890995  391    0  30   1
# 15  92.890995  391    0  30   1
# 16  93.127962  391    0  29   2
# 17  63.270142  266  125  30   1
# 18  63.270142  266  125  30   1
# 19  62.085308  261  130  30   1
# 20  54.739336  230  161  29   2
# 21  60.189573  254  137  31   0
# 22  58.767773  248  143  31   0
# 23  48.341232  204  187  30   1
# 24  53.791469  226  165  30   1
# 25  53.791469  226  165  30   1
# 26  52.369668  220  171  30   1
# 27  43.127962  181  210  29   2
# 28  49.526066  209  182  31   0
# 29  47.867299  202  189  31   0
# 30  34.597156  146  245  30   1
# 31  92.890995  391    0  30   1
# 32  92.890995  391    0  30   1
# 33  92.890995  391    0  30   1
# 34  93.127962  391    0  29   2
# 35  65.165877  274  117  30   1
# 36  65.165877  274  117  30   1
# 37  63.744076  268  123  30   1
# 38  55.687204  234  157  29   2
# 39  62.559242  264  127  31   0
# 40  60.900474  257  134  31   0
# 41  49.763033  210  181  30   1
# 42  55.924171  235  156  30   1
# 43  55.924171  235  156  30   1
# 44  54.265403  228  163  30   1
# 45  44.549763  187  204  29   2
# 46  52.132701  220  171  31   0
# 47  50.236967  212  179  31   0
# 48  36.255924  153  238  30   1

# %%
#print(f"{data} sorted by F1")
#sorted_table = table.sort_values(by='F1', ascending=False)
#sorted_table
